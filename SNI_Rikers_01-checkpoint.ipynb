# %%
January_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': 0,
               '6-7 AM': 0,
               '7-8 AM': .93,
               '8-9 AM': .323,
               '9-10 AM': .408,
               '10-11 AM': .447,
               '11AM-12PM': .455,
               '12-1PM': .460,
               '1-2PM': .432,
               '2-3PM': .403,
               '3-4PM': .328,
               '4-5PM': .116,
               '5-6 PM': 0,
               '6-7 PM': 0,
               '7-8 PM': 0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
                    }
for hours in January_Data.keys(): # Labels the hours 
    hours = hours
for SNI in January_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in January_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(January_Data.values()) # Daily Average
monthly_total = daily_total * 31
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total ) #Daily Average and Monthly
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0
# Hours: 6-7 AM Output: 0
# Hours: 7-8 AM Output: 0.93
# Hours: 8-9 AM Output: 0.323
# Hours: 9-10 AM Output: 0.408
# Hours: 10-11 AM Output: 0.447
# Hours: 11AM-12PM Output: 0.455
# Hours: 12-1PM Output: 0.46
# Hours: 1-2PM Output: 0.432
# Hours: 2-3PM Output: 0.403
# Hours: 3-4PM Output: 0.328
# Hours: 4-5PM Output: 0.116
# Hours: 5-6 PM Output: 0
# Hours: 6-7 PM Output: 0
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.302 Total Monthly Average: 133.362

# %%
Feburary_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': 0,
               '6-7 AM': 0,
               '7-8 AM': .201,
               '8-9 AM': .372,
               '9-10 AM': .433,
               '10-11 AM': .474,
               '11AM-12PM': .489,
               '12-1PM': .493,
               '1-2PM': .475,
               '2-3PM': .443,
               '3-4PM': .396,
               '4-5PM': .279,
               '5-6 PM': .038,
               '6-7 PM': 0,
               '7-8 PM': 0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0 ,
                }
for hours in Feburary_Data.keys(): # Labels the hours 
    hours = hours
for SNI in Feburary_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in Feburary_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(Feburary_Data.values()) # Daily Average
monthly_total = daily_total * 28
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0
# Hours: 6-7 AM Output: 0
# Hours: 7-8 AM Output: 0.201
# Hours: 8-9 AM Output: 0.372
# Hours: 9-10 AM Output: 0.433
# Hours: 10-11 AM Output: 0.474
# Hours: 11AM-12PM Output: 0.489
# Hours: 12-1PM Output: 0.493
# Hours: 1-2PM Output: 0.475
# Hours: 2-3PM Output: 0.443
# Hours: 3-4PM Output: 0.396
# Hours: 4-5PM Output: 0.279
# Hours: 5-6 PM Output: 0.038
# Hours: 6-7 PM Output: 0
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.093 Total Monthly Average: 114.604

# %%
March_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': 0,
               '6-7 AM': .109,
               '7-8 AM': .323,
               '8-9 AM': .409,
               '9-10 AM': .449,
               '10-11 AM': .474,
               '11AM-12PM': .489,
               '12-1PM': .485,
               '1-2PM': .464,
               '2-3PM': .428,
               '3-4PM': .369,
               '4-5PM': .310,
               '5-6 PM': .147,
               '6-7 PM': 0,
               '7-8 PM': 0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
                }
for hours in March_Data.keys(): # Labels the hours 
    hours = hours
for SNI in March_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in March_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(March_Data.values()) # Daily Average
monthly_total = daily_total * 31
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0
# Hours: 6-7 AM Output: 0.109
# Hours: 7-8 AM Output: 0.323
# Hours: 8-9 AM Output: 0.409
# Hours: 9-10 AM Output: 0.449
# Hours: 10-11 AM Output: 0.474
# Hours: 11AM-12PM Output: 0.489
# Hours: 12-1PM Output: 0.485
# Hours: 1-2PM Output: 0.464
# Hours: 2-3PM Output: 0.428
# Hours: 3-4PM Output: 0.369
# Hours: 4-5PM Output: 0.31
# Hours: 5-6 PM Output: 0.147
# Hours: 6-7 PM Output: 0
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.4559999999999995 Total Monthly Average: 138.136

# %%
April_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': .057,
               '6-7 AM': .250,
               '7-8 AM': .355,
               '8-9 AM': .423,
               '9-10 AM': .470,
               '10-11 AM': .492,
               '11AM-12PM': .497,
               '12-1PM': .487,
               '1-2PM': .471,
               '2-3PM': .431,
               '3-4PM': .384,
               '4-5PM': .321,
               '5-6 PM': .212,
               '6-7 PM': .031,
               '7-8 PM': 0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
                 }
for hours in April_Data.keys(): # Labels the hours 
    hours = hours
for SNI in April_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in April_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(April_Data.values()) # Daily Average
monthly_total = daily_total * 30
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0.057
# Hours: 6-7 AM Output: 0.25
# Hours: 7-8 AM Output: 0.355
# Hours: 8-9 AM Output: 0.423
# Hours: 9-10 AM Output: 0.47
# Hours: 10-11 AM Output: 0.492
# Hours: 11AM-12PM Output: 0.497
# Hours: 12-1PM Output: 0.487
# Hours: 1-2PM Output: 0.471
# Hours: 2-3PM Output: 0.431
# Hours: 3-4PM Output: 0.384
# Hours: 4-5PM Output: 0.321
# Hours: 5-6 PM Output: 0.212
# Hours: 6-7 PM Output: 0.031
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.880999999999999 Total Monthly Average: 146.42999999999998

# %%
May_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': .006,
               '5-6 AM': .139,
               '6-7 AM': .264,
               '7-8 AM': .338,
               '8-9 AM': .398,
               '9-10 AM': .446,
               '10-11 AM': .463,
               '11AM-12PM': .473,
               '12-1PM': .467,
               '1-2PM': .435,
               '2-3PM': .409,
               '3-4PM': .364,
               '4-5PM': .306,
               '5-6 PM': .225,
               '6-7 PM': .085,
               '7-8 PM': 0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
           }
for hours in May_Data.keys(): # Labels the hours 
    hours = hours
for SNI in May_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in May_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(May_Data.values()) # Daily Average
monthly_total = daily_total * 31
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0.006
# Hours: 5-6 AM Output: 0.139
# Hours: 6-7 AM Output: 0.264
# Hours: 7-8 AM Output: 0.338
# Hours: 8-9 AM Output: 0.398
# Hours: 9-10 AM Output: 0.446
# Hours: 10-11 AM Output: 0.463
# Hours: 11AM-12PM Output: 0.473
# Hours: 12-1PM Output: 0.467
# Hours: 1-2PM Output: 0.435
# Hours: 2-3PM Output: 0.409
# Hours: 3-4PM Output: 0.364
# Hours: 4-5PM Output: 0.306
# Hours: 5-6 PM Output: 0.225
# Hours: 6-7 PM Output: 0.085
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.818 Total Monthly Average: 149.35799999999998

# %%
June_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': .010,
               '5-6 AM': .157,
               '6-7 AM': .263,
               '7-8 AM': .334,
               '8-9 AM': .402,
               '9-10 AM': .448,
               '10-11 AM': .476,
               '11AM-12PM': .476,
               '12-1PM': .464,
               '1-2PM': .438,
               '2-3PM': .400,
               '3-4PM': .349,
               '4-5PM': .293,
               '5-6 PM': .230,
               '6-7 PM': .128,
               '7-8 PM':  .006,
               '8-9 PM': 0,
               '10-11 PM': 0 ,
               '11PM-12 AM': 0,
                }
for hours in June_Data.keys(): # Labels the hours 
    hours = hours
for SNI in June_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in June_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(June_Data.values()) # Daily Average
monthly_total = daily_total * 30
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0.01
# Hours: 5-6 AM Output: 0.157
# Hours: 6-7 AM Output: 0.263
# Hours: 7-8 AM Output: 0.334
# Hours: 8-9 AM Output: 0.402
# Hours: 9-10 AM Output: 0.448
# Hours: 10-11 AM Output: 0.476
# Hours: 11AM-12PM Output: 0.476
# Hours: 12-1PM Output: 0.464
# Hours: 1-2PM Output: 0.438
# Hours: 2-3PM Output: 0.4
# Hours: 3-4PM Output: 0.349
# Hours: 4-5PM Output: 0.293
# Hours: 5-6 PM Output: 0.23
# Hours: 6-7 PM Output: 0.128
# Hours: 7-8 PM Output: 0.006
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.8740000000000006 Total Monthly Average: 146.22000000000003

# %%
July_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': .005,
               '5-6 AM': .129,
               '6-7 AM': .265,
               '7-8 AM': .347,
               '8-9 AM': .414,
               '9-10 AM': .463,
               '10-11 AM': .478,
               '11AM-12PM': .479,
               '12-1PM': .458,
               '1-2PM': .427,
               '2-3PM': .404,
               '3-4PM': .362,
               '4-5PM': .308,
               '5-6 PM': .232,
               '6-7 PM': .116,
               '7-8 PM': .005,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
                }
for hours in July_Data.keys(): # Labels the hours 
    hours = hours
for SNI in July_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in July_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(July_Data.values()) # Daily Average
monthly_total = daily_total * 31
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0.005
# Hours: 5-6 AM Output: 0.129
# Hours: 6-7 AM Output: 0.265
# Hours: 7-8 AM Output: 0.347
# Hours: 8-9 AM Output: 0.414
# Hours: 9-10 AM Output: 0.463
# Hours: 10-11 AM Output: 0.478
# Hours: 11AM-12PM Output: 0.479
# Hours: 12-1PM Output: 0.458
# Hours: 1-2PM Output: 0.427
# Hours: 2-3PM Output: 0.404
# Hours: 3-4PM Output: 0.362
# Hours: 4-5PM Output: 0.308
# Hours: 5-6 PM Output: 0.232
# Hours: 6-7 PM Output: 0.116
# Hours: 7-8 PM Output: 0.005
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.8919999999999995 Total Monthly Average: 151.652

# %%
August_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': .060,
               '6-7 AM': .225,
               '7-8 AM': .328,
               '8-9 AM': .398,
               '9-10 AM': .451,
               '10-11 AM': .477,
               '11AM-12PM':.469,
               '12-1PM': .455,
               '1-2PM': .425,
               '2-3PM': .391,
               '3-4PM': .351,
               '4-5PM': .294,
               '5-6 PM': .205,
               '6-7 PM': .051,
               '7-8 PM': 0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
                  }
for hours in August_Data.keys(): # Labels the hours 
    hours = hours
for SNI in August_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in August_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(August_Data.values()) # Daily Average
monthly_total = daily_total * 31
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0.06
# Hours: 6-7 AM Output: 0.225
# Hours: 7-8 AM Output: 0.328
# Hours: 8-9 AM Output: 0.398
# Hours: 9-10 AM Output: 0.451
# Hours: 10-11 AM Output: 0.477
# Hours: 11AM-12PM Output: 0.469
# Hours: 12-1PM Output: 0.455
# Hours: 1-2PM Output: 0.425
# Hours: 2-3PM Output: 0.391
# Hours: 3-4PM Output: 0.351
# Hours: 4-5PM Output: 0.294
# Hours: 5-6 PM Output: 0.205
# Hours: 6-7 PM Output: 0.051
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.579999999999999 Total Monthly Average: 141.97999999999996

# %%
September_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': .012,
               '6-7 AM': .216,
               '7-8 AM': .351,
               '8-9 AM': .419,
               '9-10 AM': .466,
               '10-11 AM':  .489,
               '11AM-12PM': .492,
               '12-1PM': .482,
               '1-2PM': .452,
               '2-3PM': .420,
               '3-4PM': .380,
               '4-5PM': .331,
               '5-6 PM': .189,
               '6-7 PM': .009,
               '7-8 PM': 0,
               '8-9 PM': 0 ,
               '10-11 PM': 0 ,
               '11PM-12 AM': 0,
                 }
for hours in September_Data.keys(): # Labels the hours 
    hours = hours
for SNI in September_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in September_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(September_Data.values()) # Daily Average
monthly_total = daily_total * 30
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0.012
# Hours: 6-7 AM Output: 0.216
# Hours: 7-8 AM Output: 0.351
# Hours: 8-9 AM Output: 0.419
# Hours: 9-10 AM Output: 0.466
# Hours: 10-11 AM Output: 0.489
# Hours: 11AM-12PM Output: 0.492
# Hours: 12-1PM Output: 0.482
# Hours: 1-2PM Output: 0.452
# Hours: 2-3PM Output: 0.42
# Hours: 3-4PM Output: 0.38
# Hours: 4-5PM Output: 0.331
# Hours: 5-6 PM Output: 0.189
# Hours: 6-7 PM Output: 0.009
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 4.708 Total Monthly Average: 141.24

# %%
October_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0 ,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': 0,
               '6-7 AM': .104,
               '7-8 AM': .321,
               '8-9 AM': .406,
               '9-10 AM': .445,
               '10-11 AM': .467,
               '11AM-12PM': .466,
               '12-1PM': .449,
               '1-2PM': .411,
               '2-3PM': .380,
               '3-4PM': .311,
               '4-5PM': .187,
               '5-6 PM': .009,
               '6-7 PM': 0,
               '7-8 PM':  0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
               }
for hours in October_Data.keys(): # Labels the hours 
    hours = hours
for SNI in October_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in October_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(October_Data.values()) # Daily Average
monthly_total = daily_total * 31
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0
# Hours: 6-7 AM Output: 0.104
# Hours: 7-8 AM Output: 0.321
# Hours: 8-9 AM Output: 0.406
# Hours: 9-10 AM Output: 0.445
# Hours: 10-11 AM Output: 0.467
# Hours: 11AM-12PM Output: 0.466
# Hours: 12-1PM Output: 0.449
# Hours: 1-2PM Output: 0.411
# Hours: 2-3PM Output: 0.38
# Hours: 3-4PM Output: 0.311
# Hours: 4-5PM Output: 0.187
# Hours: 5-6 PM Output: 0.009
# Hours: 6-7 PM Output: 0
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 3.9559999999999995 Total Monthly Average: 122.63599999999998

# %%
November_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': 0,
               '6-7 AM': .011,
               '7-8 AM': .225,
               '8-9 AM': .379,
               '9-10 AM': .430,
               '10-11 AM': .457,
               '11AM-12PM':.469,
               '12-1PM': .457,
               '1-2PM': .423,
               '2-3PM': .381,
               '3-4PM': .286,
               '4-5PM': .052,
               '5-6 PM': 0,
               '6-7 PM': 0,
               '7-8 PM':  0,
               '8-9 PM': 0,
               '10-11 PM': 0,
               '11PM-12 AM': 0,
                }
for hours in November_Data.keys(): # Labels the hours 
    hours = hours
for SNI in November_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in November_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(November_Data.values()) # Daily Average
monthly_total = daily_total * 30
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0
# Hours: 6-7 AM Output: 0.011
# Hours: 7-8 AM Output: 0.225
# Hours: 8-9 AM Output: 0.379
# Hours: 9-10 AM Output: 0.43
# Hours: 10-11 AM Output: 0.457
# Hours: 11AM-12PM Output: 0.469
# Hours: 12-1PM Output: 0.457
# Hours: 1-2PM Output: 0.423
# Hours: 2-3PM Output: 0.381
# Hours: 3-4PM Output: 0.286
# Hours: 4-5PM Output: 0.052
# Hours: 5-6 PM Output: 0
# Hours: 6-7 PM Output: 0
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 3.5700000000000003 Total Monthly Average: 107.10000000000001

# %%
December_Data = {
                '12-1 AM': 0,
                '1-2AM': 0,
                '2-3AM': 0,
                '3-4 AM': 0,
                '4-5 AM': 0,
               '5-6 AM': 0,
               '6-7 AM': 0,
               '7-8 AM': .091,
               '8-9 AM': .305,
               '9-10 AM': .383,
               '10-11 AM': .415,
               '11AM-12PM':.430,
               '12-1PM': .426,
               '1-2PM': .395,
               '2-3PM': .350,
               '3-4PM': .249,
               '4-5PM': .018,
               '5-6 PM': 0,
               '6-7 PM': 0,
               '7-8 PM':  0,
               '8-9 PM': 0,
               '10-11 PM': 0 ,
               '11PM-12 AM': 0,
                }
for hours in December_Data.keys(): # Labels the hours 
    hours = hours
for SNI in December_Data.values(): # Labels the SNI and converts it to the output expected via uM6 effiency
    output = SNI * .30
for hours,output in December_Data.items(): # prints data 
     print("Hours: %s" % hours , "Output: %s" % output)
daily_total = sum(December_Data.values()) # Daily Average
monthly_total = daily_total * 31
print("Total Daily Average: %s" % daily_total, "Total Monthly Average: %s" % monthly_total )
# Out:
# Hours: 12-1 AM Output: 0
# Hours: 1-2AM Output: 0
# Hours: 2-3AM Output: 0
# Hours: 3-4 AM Output: 0
# Hours: 4-5 AM Output: 0
# Hours: 5-6 AM Output: 0
# Hours: 6-7 AM Output: 0
# Hours: 7-8 AM Output: 0.091
# Hours: 8-9 AM Output: 0.305
# Hours: 9-10 AM Output: 0.383
# Hours: 10-11 AM Output: 0.415
# Hours: 11AM-12PM Output: 0.43
# Hours: 12-1PM Output: 0.426
# Hours: 1-2PM Output: 0.395
# Hours: 2-3PM Output: 0.35
# Hours: 3-4PM Output: 0.249
# Hours: 4-5PM Output: 0.018
# Hours: 5-6 PM Output: 0
# Hours: 6-7 PM Output: 0
# Hours: 7-8 PM Output: 0
# Hours: 8-9 PM Output: 0
# Hours: 10-11 PM Output: 0
# Hours: 11PM-12 AM Output: 0
# Total Daily Average: 3.062 Total Monthly Average: 94.922
